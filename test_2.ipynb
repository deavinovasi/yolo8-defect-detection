# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics roboflow

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="o2PmgoWTtiN0VlO5rrku")
project = rf.workspace("dea-solagratia-simamora").project("test-2-8tply")
dataset = project.version(1).download("yolov8")

# %%
# !ls /content

# %%
# !cp -r /content/test-2-1 /content/drive/MyDrive/

# %%
# !ls /content/drive/MyDrive

# %%
# !yolo detect train \
data=/content/drive/MyDrive/test-2-1/data.yaml \
model=yolov8n.pt \
epochs=100 \
imgsz=640 \
project=/content/drive/MyDrive/yolo-training \
name=seal

# %%
# !ls /content/drive/MyDrive/yolo-training/seal/weights

# %%
# !cp -r /content/drive/MyDrive/yolo-training/seal /content/drive/MyDrive/backup-seal

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !yolo detect predict \
model=/content/drive/MyDrive/best.pt \
source=/content/RLC-810WA-20260204_143739.jpg

# %%
from IPython.display import Image
Image('/content/runs/detect/predict/RLC-810WA-20260204_143739.jpg')

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !yolo detect predict \
model=/content/drive/MyDrive/best.pt \
source=/content/RLC-810WA-0-20260227103521-20260227103633.mp4

# %%
import os
os.listdir('/content/runs/detect/predict')

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics

# %%
from google.colab import files
uploaded = files.upload()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/yolo-training/seal/weights/best.pt")

# %%
results = model.predict(
    source="RLC-810WA-0-20260227103521-20260227103633.mp4",
    save=True,
    conf=0.5,
    iou=0.5,
    imgsz=320,
    vid_stride=2,
    max_det=10,
    stream=True
)

# %%
import os
os.listdir('/content/runs/detect/predict')

# %%
from IPython.display import Video
Video('/content/runs/detect/predict/RLC-810WA-0-20260227103521-20260227103633.avi')

# %%
# !ffmpeg -i /content/runs/detect/predict/RLC-810WA-0-20260227103521-20260227103633.avi \
/content/runs/detect/predict/output.mp4

# %%
from IPython.display import Video
Video('/content/runs/detect/predict/output.mp4')

# %%
from IPython.display import Video
Video('RLC-810WA-0-20260227103521-20260227103633.mp4')

# %%
# !ffmpeg -i RLC-810WA-0-20260227103521-20260227103633.mp4 \
-vcodec libx264 -acodec aac \
converted.mp4

# %%
from IPython.display import Video
Video('converted.mp4')

# %%
# !ffmpeg -i RLC-810WA-0-20260227103521-20260227103633.mp4 \
-vf "fps=20,scale=1280:720" \
-c:v libx264 -preset fast -crf 23 \
converted.mp4

# %%
from IPython.display import Video
Video('converted.mp4')

# %%
# !ls -lh

# %%
from google.colab import files
files.download('converted.mp4')

# %%
# !ffmpeg -i /content/runs/detect/predict/RLC-810WA-0-20260227103521-20260227103633.avi -vcodec libx264 -acodec aac result.mp4

# %%
# !ls runs/detect/train/weights

# %%
# !ls runs/detect/train

# %%
# !find /content -name "best.pt"

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !yolo detect predict \
model=/content/drive/MyDrive/best.pt \
source=/content/RLC-810WA-0-20260227103521-20260227103633.mp4

# %%
# !ffmpeg -y -i /content/runs/detect/predict/RLC-810WA-0-20260227103521-20260227103633.avi \
  -vcodec libx264 -crf 23 -pix_fmt yuv420p \
  /content/runs/detect/predict/output.mp4

# %%
from IPython.display import Video
Video('/content/runs/detect/predict/output.mp4', embed=True, width=640)

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics
